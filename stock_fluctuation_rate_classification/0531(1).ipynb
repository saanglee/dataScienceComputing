# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score
from scipy.stats import randint

# %%
# Load datasets
train_path = './data/train.csv'
test_path = './data/test.csv'
sample_submission_path = './data/sample_submission.csv'

train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)
sample_submission = pd.read_csv(sample_submission_path)
sample_submission_df = pd.read_csv(sample_submission_path)

# %%
# Fill missing values in 'PER' and 'ROE' columns with the median value of each column
train_df['PER'].fillna(train_df['PER'].median(), inplace=True)
train_df['ROE'].fillna(train_df['ROE'].median(), inplace=True)
test_df['PER'].fillna(test_df['PER'].median(), inplace=True)
test_df['ROE'].fillna(test_df['ROE'].median(), inplace=True)

# Features and target variable
X = train_df.drop(columns=['id', 'label'])
y = train_df['label']

# Standardize the feature data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
test_df_scaled = scaler.transform(test_df.drop(columns=['id']))

# Split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Initialize the models with RandomizedSearchCV for hyperparameter tuning
rf_model = RandomForestClassifier(random_state=42)
rf_param_dist = {
    'n_estimators': randint(100, 500),
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': randint(2, 11),
    'min_samples_leaf': randint(1, 11)
}

rf_random = RandomizedSearchCV(estimator=rf_model, param_distributions=rf_param_dist, n_iter=100, cv=3, verbose=2, random_state=42, n_jobs=-1)

# Fit the RandomizedSearchCV model
rf_random.fit(X_train, y_train)

# Extract the best model from RandomizedSearchCV
best_rf_model = rf_random.best_estimator_

# Initialize and fit GradientBoostingClassifier
gb_model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
gb_model.fit(X_train, y_train)

# Initialize and fit ExtraTreesClassifier
et_model = ExtraTreesClassifier(n_estimators=200, max_depth=20, random_state=42)
et_model.fit(X_train, y_train)

# Create a VotingClassifier with the best model from RandomizedSearchCV, GradientBoosting, and ExtraTrees
voting_model = VotingClassifier(estimators=[('rf', best_rf_model), ('gb', gb_model), ('et', et_model)], voting='hard')

# Train the VotingClassifier
voting_model.fit(X_train, y_train)

# Validate the model
y_pred = voting_model.predict(X_val)
accuracy = accuracy_score(y_val, y_pred)
print(f"Validation Accuracy: {accuracy}")

# Make predictions on the test set
test_predictions = voting_model.predict(test_df_scaled)

# Prepare the submission file
sample_submission['label'] = test_predictions
sample_submission.to_csv('submission.csv', index=False)

print("Submission file has been created.")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /var/folders/gc/m21rb2tx2rscyrndrr3qsj280000gn/T/ipykernel_19221/3020804963.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['PER'].fillna(train_df['PER'].median(), inplace=True)
# /var/folders/gc/m21rb2tx2rscyrndrr3qsj280000gn/T/ipykernel_19221/3020804963.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['ROE'].fillna(train_df['ROE'].median(), inplace=True)
# /var/folders/gc/m21rb2tx2rscyrndrr3qsj280000gn/T/ipykernel_19221/3020804963.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_df['PER'].fillna(test_df['PER'].median(), inplace=True)
# /var/folders/gc/m21rb2tx2rscyrndrr3qsj280000gn/T/ipykernel_19221/3020804963.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_df['ROE'].fillna(test_df['ROE'].median(), inplace=True)
# [CV] END max_depth=30, min_samples_leaf=8, min_samples_split=6, n_estimators=202; total time=   0.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=6, n_estimators=199; total time=   0.6s
# [CV] END max_depth=30, min_samples_leaf=8, min_samples_split=6, n_estimators=202; total time=   0.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=6, n_estimators=199; total time=   0.6s
# [CV] END max_depth=30, min_samples_leaf=8, min_samples_split=6, n_estimators=202; total time=   0.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=6, n_estimators=199; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=3, min_samples_split=8, n_estimators=430; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=3, min_samples_split=8, n_estimators=430; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=3, min_samples_split=8, n_estimators=430; total time=   1.3s
# [CV] END max_depth=30, min_samples_leaf=6, min_samples_split=3, n_estimators=291; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=6, n_estimators=357; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split
total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=9, n_estimators=424; total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=9, n_estimators=424; total time=   1.4s
# [CV] END max_depth=None, min_samples_leaf=9, min_samples_split=7, n_estimators=448; total time=   1.2s
# [CV] END max_depth=None, min_samples_leaf=9, min_samples_split=7, n_estimators=448; total time=   1.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=7, n_estimators=494; total time=   1.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=7, n_estimators=494; total time=   1.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=7, n_estimators=494; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=9, min_samples_split=7, n_estimators=448; total time=   1.4s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=445; total time=   1.5s
# [CV] END max_depth=30, min_samples_leaf=9, min_samples_split=2, n_estimators=227; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=445; total time=   1.6s
# [CV] END max_depth=30, min_samples_leaf=9, min_samples_split=2, n_estimators=227; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=445; total time=   1.5s
# [CV] END max_depth=20, min_samples_leaf=3, min_samples_split=5, n_estimators=451; total time=   1.4s
# [CV] END max_depth=30, min_samples_leaf=9, min_samples_split=2, n_estimators=227; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=3, min_samples_split=5, n_estimators=451; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=3, min_samples_split=5, n_estimators=451; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=366; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=9, min_samples_split=10, n_estimators=250; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=366; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=2, n_estimators=366; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=9, min_samples_split=10, n_estimators=250; total time=   0.7s
# [CV] END max_depth=30, min_samples_leaf=9, min_samples_split=10, n_estimators=250; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=10, n_estimators=159; total time=   0.5s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=4, n_estimators=362; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=10, n_estimators=159; total time=   0.5s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=10, n_estimators=159; total time=   0.5s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=4, n_estimators=362; total time=   1.1s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=4, n_estimators=362; total time=   1.1s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=6, n_estimators=259; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=403; total time=   1.4s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=6, n_estimators=259; total time=   1.0s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=6, n_estimators=259; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=10, n_estimators=332; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=403; total time=   1.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=403; total time=   1.5s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=10, n_estimators=332; total time=   1.0s
# [CV] END max_depth=50, min_samples_leaf=8, min_samples_split=2, n_estimators=215; total time=   0.7s
# [CV] END max_depth=50, min_samples_leaf=8, min_samples_split=2, n_estimators=215; total time=   0.7s
# [CV] END max_depth=50, min_samples_leaf=8, min_samples_split=2, n_estimators=215; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=3, min_samples_split=4, n_estimators=251; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=3, min_samples_split=4, n_estimators=251; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=10, n_estimators=332; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=3, min_samples_split=4, n_estimators=251; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=9, n_estimators=203; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=9, n_estimators=203; total time=   0.7s
# [CV] END max_depth=30, min_samples_leaf=3, min_samples_split=10, n_estimators=198; total time=   0.7s
# [CV] END max_depth=30, min_samples_leaf=3, min_samples_split=10, n_estimators=198; total time=   0.7s
# [CV] END max_depth=30, min_samples_leaf=3, min_samples_split=10, n_estimators=198; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=9, n_estimators=203; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=3, n_estimators=293; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=3, n_estimators=293; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=3, n_estimators=293; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=260; total time=   0.9s
# [CV] END max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=260; total time=   0.8s
# [CV] END max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=260; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=8, min_samples_split=9, n_estimators=234; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=8, min_samples_split=9, n_estimators=234; total time=   0.7s
# [CV] END max_depth=30, min_samples_leaf=8, min_samples_split=9, n_estimators=234; total time=   0.8s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=6, n_estimators=403; total time=   1.5s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=6, n_estimators=403; total time=   1.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=275; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=6, n_estimators=403; total time=   1.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=275; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=275; total time=   1.2s
# [CV] END max_depth=30, min_samples_leaf=3, min_samples_split=7, n_estimators=474; total time=   1.6s
# [CV] END max_depth=50, min_samples_leaf=6, min_samples_split=7, n_estimators=464; total time=   1.5s
# [CV] END max_depth=30, min_samples_leaf=3, min_samples_split=7, n_estimators=474; total time=   1.8s
# [CV] END max_depth=30, min_samples_leaf=3, min_samples_split=7, n_estimators=474; total time=   1.7s
# [CV] END max_depth=50, min_samples_leaf=6, min_samples_split=7, n_estimators=464; total time=   1.4s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=9, n_estimators=382; total time=   1.2s
# [CV] END max_depth=50, min_samples_leaf=6, min_samples_split=7, n_estimators=464; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=9, n_estimators=382; total time=   1.5s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=9, n_estimators=382; total time=   1.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=6, n_estimators=385; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=6, n_estimators=385; total time=   1.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=6, n_estimators=385; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=6, n_estimators=416; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=4, n_estimators=291; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=6, n_estimators=416; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=6, n_estimators=416; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=6, n_estimators=105; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=6, n_estimators=105; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=6, n_estimators=105; total time=   0.4s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=4, n_estimators=291; total time=   1.2s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=4, n_estimators=291; total time=   1.1s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=6, n_estimators=194; total time=   0.8s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=6, n_estimators=194; total time=   0.8s
# [CV] END max_depth=20, min_samples_leaf=9, min_samples_split=6, n_estimators=379; total time=   1.3s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=6, n_estimators=194; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=9, min_samples_split=6, n_estimators=379; total time=   1.3s
# [CV] END max_depth=20, min_samples_leaf=9, min_samples_split=6, n_estimators=379; total time=   1.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=290; total time=   1.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=290; total time=   1.3s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=8, n_estimators=260; total time=   1.1s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=8, n_estimators=260; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=290; total time=   1.3s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=8, n_estimators=260; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=322; total time=   1.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=322; total time=   1.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=322; total time=   1.4s
# [CV] END max_depth=50, min_samples_leaf=7, min_samples_split=3, n_estimators=226; total time=   0.9s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=4, n_estimators=459; total time=   1.5s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=4, n_estimators=459; total time=   1.7s
# [CV] END max_depth=50, min_samples_leaf=8, min_samples_split=3, n_estimators=387; total time=   1.5s
# [CV] END max_depth=50, min_samples_leaf=8, min_samples_split=3, n_estimators=387; total time=   1.6s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=4, n_estimators=459; total time=   1.7s
# [CV] END max_depth=50, min_samples_leaf=7, min_samples_split=3, n_estimators=226; total time=   0.8s
# [CV] END max_depth=50, min_samples_leaf=8, min_samples_split=3, n_estimators=387; total time=   1.6s
# [CV] END max_depth=50, min_samples_leaf=7, min_samples_split=3, n_estimators=226; total time=   0.7s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=8, n_estimators=125; total time=   0.4s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=8, n_estimators=125; total time=   0.4s
# [CV] END max_depth=None, min_samples_leaf=9, min_samples_split=7, n_estimators=275; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=9, min_samples_split=7, n_estimators=275; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=3, n_estimators=372; total time=   1.2s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=8, n_estimators=125; total time=   0.4s
# [CV] END max_depth=None, min_samples_leaf=9, min_samples_split=7, n_estimators=275; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=3, n_estimators=372; total time=   1.2s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=3, n_estimators=372; total time=   1.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=112; total time=   0.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=112; total time=   0.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=112; total time=   0.4s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=8, n_estimators=412; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=3, min_samples_split=8, n_estimators=242; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=8, n_estimators=412; total time=   1.4s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=8, n_estimators=412; total time=   1.4s
# [CV] END max_depth=50, min_samples_leaf=3, min_samples_split=8, n_estimators=242; total time=   1.2s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=363; total time=   1.4s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=363; total time=   1.4s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=363; total time=   1.4s
# [CV] END max_depth=50, min_samples_leaf=3, min_samples_split=8, n_estimators=242; total time=   0.9s
# [CV] END max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=285; total time=   0.9s
# [CV] END max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=285; total time=   0.9s
# [CV] END max_depth=50, min_samples_leaf=3, min_samples_split=10, n_estimators=285; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=3, n_estimators=387; total time=   1.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=3, n_estimators=387; total time=   1.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=3, n_estimators=387; total time=   1.4s
# Validation Accuracy: 0.6285714285714286
# Submission file has been created.

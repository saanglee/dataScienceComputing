# %% [markdown]
# - train each model using each mode and evaluate
# - SVM, Naive Bayes, Decision Tree, K-neighbors, Random Forest

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('train.csv')

data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
X = data.iloc[:, :-1] # 처음부터 마지막 열 전까지 모든 열을 선택, X는 입력변수, 즉 특성 feature
X.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
y = data.iloc[:, -1] # Label, 즉 타겟변수
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %%
from sklearn.model_selection import train_test_split

from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# import sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=2024)

# %%
# Naive Bayes

clf_nb = GaussianNB()
clf_nb.fit(X_train, y_train)
y_pred_nb = clf_nb.predict(X_test)

report_nb = classification_report(y_test, y_pred_nb)

# %%
# Decision Tree

clf_dt = tree.DecisionTreeClassifier()
clf_dt.fit(X_train, y_train)            # train데이터를 이용해 모델을 학습시킴
y_pred_dt = clf_dt.predict(X_test)      # 학습된 모델을 이용해 test데이터에 대한 예측값을 구함

report_dt = classification_report(y_test, y_pred_dt) # 실제값과 예측값을 비교하여 성능 평가

# %%
# Random Forest
clf_rf = RandomForestClassifier()
clf_rf.fit(X_train, y_train)
y_pred_rf = clf_rf.predict(X_test)

report_rf = classification_report(y_test, y_pred_rf)

# %%
# SVM
clf_svm = SVC()
clf_svm.fit(X_train, y_train)
y_pred_svm = clf_svm.predict(X_test)

report_svm = classification_report(y_test, y_pred_svm)

# %%
# KNN
clf_kn = KNeighborsClassifier()
clf_kn.fit(X_train, y_train)
y_pred_kn = clf_kn.predict(X_test)

report_kn = classification_report(y_test, y_pred_rf)

# %%
print(f'Naive Bayes 분류 결과: \n {report_nb}')
print(f'Decision Tree 분류 결과: \n {report_dt}')
print(f'Random Forest 분류 결과: \n {report_rf}')
print(f'SVM 분류 결과: \n {report_svm}')
print(f'K-neighbors 분류 결과: \n {report_kn}')
# Out:
# Naive Bayes 분류 결과:
#                precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       163
#            1       0.73      0.75      0.74       156
#            2       0.75      0.69      0.72       183
#            3       0.85      0.91      0.88       158
#
#     accuracy                           0.82       660
#    macro avg       0.81      0.82      0.82       660
# weighted avg       0.81      0.82      0.81       660
#
# Decision Tree 분류 결과:
#                precision    recall  f1-score   support
#
#            0       0.85      0.92      0.88       163
#            1       0.73      0.74      0.74       156
#            2       0.81      0.72      0.76       183
#            3       0.87      0.89      0.88       158
#
#     accuracy                           0.82       660
#    macro avg       0.81      0.82      0.81       660
# weighted avg       0.81      0.82      0.81       660
#
# Random Forest 분류 결과:
# ...
